# %% [markdown]
# Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from  matplotlib.colors import ListedColormap
from knn import KNN

# %% [markdown]
# Make Database

# %%
female_data = pd.read_csv ('inputs\ANSUR II FEMALE Public.csv')
female_data = female_data.rename (columns = {'SubjectId' : 'subjectid'})
female_data.head (3)
# Out:
#    subjectid  abdominalextensiondepthsitting  ...  Weightlbs  WritingPreference
# 0      10037                             231  ...        142         Right hand
# 1      10038                             194  ...        120         Right hand
# 2      10042                             183  ...        147         Right hand
#
# [3 rows x 108 columns]

# %%
male_data = pd.read_csv ('inputs\ANSUR II MALE Public.csv' , encoding = 'latin_1')
male_data.head (3)
# Out:
#    subjectid  abdominalextensiondepthsitting  ...  Weightlbs  WritingPreference
# 0      10027                             266  ...        180         Right hand
# 1      10032                             233  ...        160          Left hand
# 2      10033                             287  ...        205          Left hand
#
# [3 rows x 108 columns]

# %%
data = pd.concat ([female_data , male_data])
data.head (3)
# Out:
#    subjectid  abdominalextensiondepthsitting  ...  Weightlbs  WritingPreference
# 0      10037                             231  ...        142         Right hand
# 1      10038                             194  ...        120         Right hand
# 2      10042                             183  ...        147         Right hand
#
# [3 rows x 108 columns]

# %% [markdown]
# Converting unit of weight, unit of height and datatype of gender
# - female = 0
# - male = 1

# %%
data ['weightkg'] = data ['weightkg'] / 10

data ['stature'] = data ['stature'] / 10

data ['Gender'] = data ['Gender'].replace(['Female' , 'Male'] , [0 , 1])
# Out:
# C:\Users\TARA\AppData\Local\Temp\ipykernel_8584\4168285863.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data ['Gender'] = data ['Gender'].replace(['Female' , 'Male'] , [0 , 1])

# %% [markdown]
# Showing weight and stature on a scatter diagram
# - female = pink
# - male = blue

# %%
cmap = ['pink' , 'lightblue']
plt.scatter (data['stature'] , data['weightkg'] , c = data['Gender'] , cmap= ListedColormap (cmap) , alpha=0.4)

plt.xlabel ('stature')
plt.ylabel ('weight')
plt.title ('Men and Women weight and stature')

plt.savefig ('outputs\weight&stature.png')
plt.show ()

# %% [markdown]
# Women and Men height
